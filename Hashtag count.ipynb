# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import os
path1 = 'twitter_timestamp.txt'
path2 = 'aggregated2.txt'
#path3 = 'debate_all_hashtags.txt'
data1 = pd.read_csv(path1, names=['timestamp', 'Number of Tweets - Baseline-1'])
data2 = pd.read_csv(path2, names=['timestamp', 'Number of Tweets - Baseline-1'])
#data3 = pd.read_csv(path3, names=['timestamp'], encoding='latin-1')
#data2.size
#data3 = data2.drop_duplicates()
#data3.size
#data3.head(100)
data2['Number of Tweets - Baseline-2'] = data1['Number of Tweets - Baseline-1'].astype(int)
data2.head()
data2.plot()
